# %%
import os
import csv
import pandas as pd
import numpy as np

# %%
#Collecting data from Resources folder

#Mortality rates

file_path = os.path.join("..","References", "Excess_mortality_during_COVID-19_pandemic.csv")

excess_mortality_df = pd.read_csv(file_path)

excess_mortality_df.head()
# Out:
#          country        region          period               year  \
# 0  #country+name     #loc+name  #date+reported  #date+reported+yy
# 1          Italy  Bergamo city            week               2015
# 2          Italy  Bergamo city            week               2015
# 3          Italy  Bergamo city            week               2015
# 4          Italy  Bergamo city            week               2015
#
#                month                 week        date            deaths  \
# 0  #date+reported+mm  #date+reported+week   #date+end  #affected+killed
# 1                  1                    2  2015-01-15                39
# 2                  1                    3  2015-01-22                31
# 3                  1                    4  2015-01-29                41
# 4                  2                    5  2015-02-05                31
#
#              expected_deaths            excess_deaths  \
# 0  #affected+killed+expected  #affected+killed+excess
# 1                         36                        3
# 2                         31                        0
# 3                         39                        2
# 4                         31                        0
#
#                excess_deaths_pct
# 0  #affected+killed+expected+pct
# 1              8.333333333333329
# 2                              0
# 3              5.128205128205138
# 4                              0

# %%
excess_mortality_df.describe()
# Out:
#        country      region period   year  month   week        date deaths  \
# count    62916       62916  62916  62916  62916  62415       62916  62916
# unique      26         201      3     12     13     53        2585   6672
# top         US  Valparaíso   week   2018      4     17  2017-04-30     23
# freq     20676         557  62414   9814   5853   1286         114    237
#
#        expected_deaths excess_deaths excess_deaths_pct
# count            62890         62890             62890
# unique            3284          2969             34285
# top                 26             0                 0
# freq               365          8649              8649

# %%
#Finding unique locations
excess_mortality_df["country"].unique()
# Out:
# array(['#country+name', 'Italy', 'Netherlands', 'Ecuador', 'Spain',
#        'France', 'Turkey', 'Indonesia', 'Russia', 'Brazil', 'Peru',
#        'Chile', 'Mexico', 'US', 'UK', 'Belgium', 'Portugal', 'Denmark',
#        'Austria', 'Germany', 'Sweden', 'South Africa', 'Norway', 'Israel',
#        'Iceland', 'Switzerland'], dtype=object)

# %%
#remove all countries except US
clean_df = excess_mortality_df[~excess_mortality_df["country"].str.contains('Italy')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Netherlands')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Ecuador')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Spain')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('France')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Turkey')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Indonesia')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Russia')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Brazil')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Peru')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Chile')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Mexico')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('UK')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Belgium')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Portugal')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Denmark')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Austria')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Germany')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Sweden')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('South Africa')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Norway')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Israel')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Iceland')]
clean_df = clean_df[~excess_mortality_df["country"].str.contains('Switzerland')]

clean_df["country"].unique()
# Out:
# <ipython-input-43-23e1dcca6101>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Netherlands')]
# <ipython-input-43-23e1dcca6101>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Ecuador')]
# <ipython-input-43-23e1dcca6101>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Spain')]
# <ipython-input-43-23e1dcca6101>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('France')]
# <ipython-input-43-23e1dcca6101>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Turkey')]
# <ipython-input-43-23e1dcca6101>:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Indonesia')]
# <ipython-input-43-23e1dcca6101>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Russia')]
# <ipython-input-43-23e1dcca6101>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Brazil')]
# <ipython-input-43-23e1dcca6101>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Peru')]
# <ipython-input-43-23e1dcca6101>:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Chile')]
# <ipython-input-43-23e1dcca6101>:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Mexico')]
# <ipython-input-43-23e1dcca6101>:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('UK')]
# <ipython-input-43-23e1dcca6101>:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Belgium')]
# <ipython-input-43-23e1dcca6101>:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Portugal')]
# <ipython-input-43-23e1dcca6101>:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Denmark')]
# <ipython-input-43-23e1dcca6101>:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Austria')]
# <ipython-input-43-23e1dcca6101>:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Germany')]
# <ipython-input-43-23e1dcca6101>:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Sweden')]
# <ipython-input-43-23e1dcca6101>:21: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('South Africa')]
# <ipython-input-43-23e1dcca6101>:22: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Norway')]
# <ipython-input-43-23e1dcca6101>:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Israel')]
# <ipython-input-43-23e1dcca6101>:24: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Iceland')]
# <ipython-input-43-23e1dcca6101>:25: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_df = clean_df[~excess_mortality_df["country"].str.contains('Switzerland')]
# array(['#country+name', 'US'], dtype=object)

# %%
clean_df["year"].unique()
# Out:
# array(['#date+reported+yy', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020'], dtype=object)

# %%
clean_US_df = clean_df[~clean_df["year"].str.contains('2013')]
clean_US_df = clean_US_df[~clean_df["year"].str.contains('2014')]
clean_US_df = clean_US_df[~clean_df["year"].str.contains('2015')]
clean_US_df = clean_US_df[~clean_df["year"].str.contains('2016')]
clean_US_df = clean_US_df[~clean_df["year"].str.contains('2017')]
clean_US_df = clean_US_df[~clean_df["year"].str.contains('2018')]
clean_US_df = clean_US_df[~clean_df["year"].str.contains('2019')]

clean_US_df["year"].unique()
# Out:
# <ipython-input-45-e89c40057390>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_US_df = clean_US_df[~clean_df["year"].str.contains('2014')]
# <ipython-input-45-e89c40057390>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_US_df = clean_US_df[~clean_df["year"].str.contains('2015')]
# <ipython-input-45-e89c40057390>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_US_df = clean_US_df[~clean_df["year"].str.contains('2016')]
# <ipython-input-45-e89c40057390>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_US_df = clean_US_df[~clean_df["year"].str.contains('2017')]
# <ipython-input-45-e89c40057390>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_US_df = clean_US_df[~clean_df["year"].str.contains('2018')]
# <ipython-input-45-e89c40057390>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean_US_df = clean_US_df[~clean_df["year"].str.contains('2019')]
# array(['#date+reported+yy', '2020'], dtype=object)

# %%
clean_US_df.head(50)
# Out:
#              country     region          period               year  \
# 0      #country+name  #loc+name  #date+reported  #date+reported+yy
# 30807             US    Alabama            week               2020
# 30808             US    Alabama            week               2020
# 30809             US    Alabama            week               2020
# 30810             US    Alabama            week               2020
# 30811             US    Alabama            week               2020
# 30812             US    Alabama            week               2020
# 30813             US    Alabama            week               2020
# 30814             US    Alabama            week               2020
# 30815             US    Alabama            week               2020
# 30816             US    Alabama            week               2020
# 30817             US    Alabama            week               2020
# 30818             US    Alabama            week               2020
# 30819             US    Alabama            week               2020
# 30820             US    Alabama            week               2020
# 30821             US    Alabama            week               2020
# 30822             US    Alabama            week               2020
# 30823             US    Alabama            week               2020
# 30824             US    Alabama            week               2020
# 30825             US    Alabama            week               2020
# 30826             US    Alabama            week               2020
# 30827             US    Alabama            week               2020
# 30828             US    Alabama            week               2020
# 30829             US    Alabama            week               2020
# 30830             US    Alabama            week               2020
# 30831             US    Alabama            week               2020
# 30832             US    Alabama            week               2020
# 30833             US    Alabama            week               2020
# 30834             US    Alabama            week               2020
# 30835             US    Alabama            week               2020
# 30836             US    Alabama            week               2020
# 30837             US    Alabama            week               2020
# 30819                       1004                       89
# 30820                       1028                      146
# 30821                       1031                      113
# 30822                        996                      157
# 30823                       1004                      147
# 30824                        986                      169
# 30825                        990                      197
# 30826                       1010                      152
# 30827                        995                      151
# 30828                        976                      140
# 30829                       1010                      171
# 30830                        939                      199
# 30831                        984                      103
# 30832                        949                      211
# 30833                        965                      258
# 30834                        985                      282
# 30835                        964                      309
# 30836                        942                      392
# 30837                        959                      405
# 30838                        937                      374
# 30839                        980                      249
# 30840                        956                      203
# 30841                        951                        6
# 31199                         88                        3
# 31200                         91                       17
# 31201                         96                        7
# 31202                         88                       14
# 31203                         86                        5
# 31204                         91                        4
# 31205                         84                        9
# 31206                         79                       10
# 31207                         91                        1
# 31208                         90                       -7
# 31209                         87                        7
# 31210                         80                      -12
# 31211                         85                        7
# 31212                         87                       14
#
#                    excess_deaths_pct
# 0      #affected+killed+expected+pct
# 30807              -2.75555555555556
# 30808             0.5253940455341564
# 30809              -6.51607298001737
# 30810             1.2126865671641838
# 30811             -5.381165919282509
# 30812             1.9981834695731209
# 30813            -0.4508566275924153
# 30814             2.0109689213893915
# 30815             10.570626753975688
# 30816              1.668211306765528
# 30817            -0.3626473254759759
# 30818              5.024154589371975
# 30819             8.8645418326693175
# 30820             14.202334630350194
# 30821             10.960232783705152
# 30822             15.763052208835333
# 30823             14.641434262948223
# 30824             17.139959432048684
# 30825              19.89898989898991
# 30826             15.049504950495034
# 30827             15.175879396984925
# 30828             14.344262295081961
# 30829             16.930693069306926
# 30830             21.192758253461122
# 30831              10.46747967479675
# 30832             22.233930453108528
# 30833             26.735751295336783
# 30834             28.629441624365484
# 30835              32.05394190871368
# 30836             41.613588110403384
# 30837             42.231491136600624
# 30838             39.914621131269996
# 30839              25.40816326530613
# 30840              21.23430962343096
# 30841             0.6309148264984117
# 31199             3.4090909090909207
# 31200             18.681318681318686
# 31201              7.291666666666671
# 31202              15.90909090909092
# 31203              5.813953488372107
# 31204              4.395604395604408
# 31205             10.714285714285722
# 31206             12.658227848101262
# 31207              1.098901098901095
# 31208            -7.7777777777777715
# 31209              8.045977011494259
# 31210                            -15
# 31211              8.235294117647058
# 31212             16.091954022988503

# %%
clean_US_df=clean_US_df.rename(columns={"region":"Jurisdiction"})
clean_US_df
# Out:
#              country Jurisdiction          period               year  \
# 0      #country+name    #loc+name  #date+reported  #date+reported+yy
# 30807             US      Alabama            week               2020
# 30808             US      Alabama            week               2020
# 30809             US      Alabama            week               2020
# 30810             US      Alabama            week               2020
# ...              ...          ...             ...                ...
# 51121             US      Wyoming            week               2020
# 51122             US      Wyoming            week               2020
# 51123             US      Wyoming            week               2020
# 51124             US      Wyoming            week               2020
# 51125             US      Wyoming            week               2020
#
#                    month                 week        date            deaths  \
# 0      #date+reported+mm  #date+reported+week   #date+end  #affected+killed
# 30807                  1                    1  2020-01-04              1094
# 30808                  1                    2  2020-01-11              1148
# 30809                  1                    3  2020-01-18              1076
# 30810                  1                    4  2020-01-25              1085
# ...                  ...                  ...         ...               ...
# 51121                  8                   31  2020-08-01                93
# 51122                  8                   32  2020-08-08               117
# 51123                  8                   33  2020-08-15               104
# 51124                  8                   34  2020-08-22                95
# 51125                  8                   35  2020-08-29                71
#
#                  expected_deaths            excess_deaths  \
# 0      #affected+killed+expected  #affected+killed+excess
# 30807                       1125                      -31
# 30808                       1142                        6
# 30809                       1151                      -75
# 30810                       1072                       13
# ...                          ...                      ...
# 51121                         85                        8
# 51122                         88                       29
# 51123                         86                       18
# 51124                         83                       12
# 51125                         87                      -16
#
#                    excess_deaths_pct
# 0      #affected+killed+expected+pct
# 30807              -2.75555555555556
# 30808             0.5253940455341564
# 30809              -6.51607298001737
# 30810             1.2126865671641838
# ...                              ...
# 51121              9.411764705882362
# 51122              32.95454545454547
# 51123             20.930232558139522
# 51124             14.457831325301214
# 51125             -18.39080459770115
#
# [1808 rows x 11 columns]

# %%
clean_US_final_df= clean_US_df.groupby('Jurisdiction').agg({"deaths":'max',
                                                   "expected_deaths":'max',
                                                       "excess_deaths": 'max',
                                                        })
clean_US_final_df.head()
# Out:
#                         deaths            expected_deaths  \
# Jurisdiction
# #loc+name     #affected+killed  #affected+killed+expected
# Alabama                    957                        996
# Alaska                      96                         96
# Arizona                   1938                       1219
# Arkansas                   759                        676
#
#                         excess_deaths
# Jurisdiction
# #loc+name     #affected+killed+excess
# Alabama                            89
# Alaska                              9
# Arizona                            98
# Arkansas                           97

# %%
clean_US_final_df["Country"]='United States'
clean_US_final_df
# Out:
#                                 deaths            expected_deaths  \
# Jurisdiction
# #loc+name             #affected+killed  #affected+killed+expected
# Alabama                            957                        996
# Alaska                              96                         96
# Arizona                           1938                       1219
# Arkansas                           759                        676
# California                        6252                       5819
# Colorado                           993                        829
# Connecticut                        941                        683
# Delaware                           282                        206
# District of Columbia                99                         99
# Florida                           5682                       4223
# Georgia                           2029                       1783
# Hawaii                             275                        249
# Idaho                              362                        298
# Illinois                          3057                       2396
# Indiana                           1616                       1451
# Iowa                               697                        688
# Kansas                             606                        598
# Kentucky                           997                        997
# Louisiana                          982                        970
# Maine                              331                        311
# Maryland                           983                        998
# Massachusetts                      998                        994
# Michigan                          3398                       2131
# Minnesota                          994                        957
# Mississippi                        903                        719
# Missouri                          1420                       1334
# Montana                            238                        229
# Nebraska                           382                        377
# Nevada                             635                        538
# New Hampshire                      302                        277
# New Jersey                        4750                       1627
# New Mexico                         463                        403
# New York                          4524                       2211
# New York City                      992                        999
# North Carolina                    2086                       1981
# North Dakota                        92                        137
# Ohio                              2815                       2696
# Oklahoma                           919                        878
# Oregon                             797                        780
# Pennsylvania                      3758                       2971
# Rhode Island                       371                        220
# South Carolina                    1358                        997
# South Dakota                       193                        171
# Tennessee                         1599                       1506
# Texas                             6077                       4243
# US                               78897                      60980
# Utah                               434                        390
# Vermont                             99                         99
# Virginia                          1673                       1484
# Washington                        1320                        989
# West Virginia                      538                        531
# Wisconsin                         1243                      997.5
# Wyoming                             99                         99
#
#                                 excess_deaths        Country
# Jurisdiction
# #loc+name             #affected+killed+excess  United States
# Alabama                                    89  United States
# Alaska                                      9  United States
# Arizona                                    98  United States
# Arkansas                                   97  United States
# California                                925  United States
